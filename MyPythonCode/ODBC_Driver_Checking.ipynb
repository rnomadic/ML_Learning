# %%
from turbodbc import connect, make_options
options = make_options(autocommit = True)

 

connection_q = connect(dsn = "cpvq", turbodbc_options = options)
#connection_p = connect(dsn = "cpv", turbodbc_options = options)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-f195b668ab26> in <module>
# ----> 1 from turbodbc import connect, make_options
#       2 options = make_options(autocommit = True)
#       3
#       4
#       5
#
# ModuleNotFoundError: No module named 'turbodbc'

# %%
conda install turboodbc
# Out:
# ^C
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install turbodbc
# Out:
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\jyotirmoyr467\AppData\Local\Continuum\miniconda3
#
#   added / updated specs:
#     - turbodbc
#
# Note: you may need to restart the kernel to use updated packages.
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.8.5
#   latest version: 4.9.2
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     abseil-cpp-20200225.2      |       ha925a31_2         1.9 MB  conda-forge
#     arrow-cpp-2.0.0            |py37h0dac82d_6_cpu        13.3 MB  conda-forge
#     aws-c-common-0.4.59        |       h8ffe710_1         151 KB  conda-forge
#     aws-c-event-stream-0.1.6   |       hb4e73fc_6          26 KB  conda-forge
# ...

# %%
from turbodbc import connect, make_options
options = make_options(autocommit = True)

 

#connection_q = connect(dsn = "cpvq", turbodbc_options = options)
connection_p = connect(dsn = "cpv", turbodbc_options = options)

# %%
from turbodbc import connect, make_options
options = make_options(autocommit = True)

 

connection_q = connect(dsn = "cpvq", turbodbc_options = options)
#connection_p = connect(dsn = "cpv", turbodbc_options = options)
