# %%
import numpy as np
import matplotlib.pyplot as plt

"The most important function in matplotlib is plot, which allows you to plot 2D data."

"Compute the x and y coordinates for points on a sine curve"

x = np.arange(0, 3* np.pi, 0.1)
y = np.sin(x)
plt.plot(x, y)
plt.show()


"Plot multiple lines"
x = np.arange(0, 3* np.pi, 0.1)
y_sin = np.sin(x)
y_cos = np.cos(x)
plt.plot(x, y_sin)
plt.plot(x, y_cos)
plt.xlabel('x axis label')
plt.ylabel('y axis label')
plt.title('sine and cosine')
plt.legend(['sine', 'cosine'])
plt.show()

"sub plotting"
x = np.arange(0, 3* np.pi, 0.1)
y_sin = np.sin(x)
y_cos = np.cos(x)

"  Set up a subplot grid that has height 2 and width 1," \
"  and set the first such subplot as active."
plt.subplot(2, 1, 1)

"Make the first plot"
plt.plot(x, y_sin)
plt.title('sine')

"set the second subplot active and make the plot"
plt.subplot(2, 1, 2)
plt.plot(x, y_cos)
plt.title('cosine ')

"Display 2 subplots"
plt.show()

# %%
#All Bot
#tmp_bot = tmp_banned[tmp_banned.Result.str.contains("bot", flags=re.IGNORECASE, na=False)]
# unique_act_cnt = list()
# for each in unique_actions:
#     cnt = all_bots[all_bots.Action == each]
#     cnt = cnt.UserID.unique()
#     #print(cnt.shape[0])
#     unique_act_cnt.append(cnt.shape[0])
# unique_act_cnt



# import numpy as np
# import matplotlib.pyplot as plt
# plt.figure(figsize=(20,10))
# index = np.arange(len(unique_act_cnt))
# p1= plt.bar(index, unique_act_cnt,  color=['black', 'red', 'green', 'blue', 'cyan', 'orange', 'purple', 'red', 'green', 'cyan', 'orange', 'yellow', 'violet'])
# plt.xlabel('Actions', fontsize=15)
# plt.ylabel('unique_act_cnt', fontsize=15)
# #plt.xticks(index, unique_actions, fontsize=10, rotation=30)
# plt.legend((p1[0], p1[1],p1[2],p1[3],p1[4],p1[5],p1[6],p1[7],p1[8],p1[9],p1[10],p1[11],p1[12]), (unique_actions[0], unique_actions[1], unique_actions[2], unique_actions[3],
#                               unique_actions[4],unique_actions[5],unique_actions[6],unique_actions[7],
#                               unique_actions[8], unique_actions[9], unique_actions[10], unique_actions[11],
#                              unique_actions[12]), fontsize=15)
# plt.title('Unique Actions of Bot', fontsize=20)



# plt.show()

# %% [markdown]
# <img src="matplot_image.png">
# #<img src="resources/sobel.png" width=200 height=200>
